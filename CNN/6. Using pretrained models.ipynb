# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step

# %%
image_path = '/content/f8bae3a6-e341-486c-a1ec-d91242747e9a.jpg'
img = image.load_img(image_path, target_size=(224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/imagenet_class_index.json
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Predicted: [('n03916031', 'perfume', np.float32(0.42027375)), ('n03476684', 'hair_slide', np.float32(0.20646009)), ('n02910353', 'buckle', np.float32(0.09956507))]

# %%
model2 = ResNet50(weights='imagenet')

# %%
image_path = '/content/happy-samoyed-dog-field-flowers.jpg'
img2 = image.load_img(image_path, target_size=(224, 224))

# %%
img2
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x = image.img_to_array(img2)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model2.predict(x)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Predicted: [('n02111889', 'Samoyed', np.float32(0.9964934)), ('n02109961', 'Eskimo_dog', np.float32(0.0012961081)), ('n02110063', 'malamute', np.float32(0.00091430685))]
